# %%
import qiskit_metal as metal

# %%
import qiskit_metal as metal
import numpy as np
from math import *
from qiskit_metal import designs, draw, Dict
from qiskit_metal.qlibrary.core import BaseQubit, QComponent
from qiskit_metal import MetalGUI
from qiskit_metal.qlibrary.qubits.star_qubit import StarQubit

design = designs.DesignPlanar()
gui = MetalGUI(design)
gui.rebuild()

StarQubit.get_template_options(design)
design.overwrite_enabled = True

qubit_options = dict(
    pos_x = '5um',
    pos_y = '5um',
    number_of_connectors = 4
)

q1 = StarQubit(design, 'Star', options=qubit_options)

gui.rebuild()
gui.autoscale()
gui.zoom_on_components(['Star'])

q1
gui.screenshot()
gui.figure.savefig('shot.png')

from IPython.display import Image, display
_disp_ops = dict(width=500)
display(Image('shot.png', **_disp_ops))

gui.main_window.close()
# Out:
# True

# %%
import qiskit_metal as metal

# %%
from qiskit_metal import designs, draw

# %%
from qiskit_metal import MetalGUI, Dict, open_docs

# %%
design = designs.DesignPlannar()
gui = MetalGUI(design)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 design = designs.DesignPlannar()
#       2 gui = MetalGUI(design)
#
# AttributeError: module 'qiskit_metal.designs' has no attribute 'DesignPlannar'

# %%
design = designs.DesignPlannar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 design = designs.DesignPlannar()
#
# AttributeError: module 'qiskit_metal.designs' has no attribute 'DesignPlannar'

# %%
design = designs.DesignPlanar()

# %%
gui = MetalGUI(design)

# %%
import qiskit_metal as metal

# %%
import qiskit_metal import designs, draw
# Out:
#   Cell In[11], line 1
#     import qiskit_metal import designs, draw
#                         ^
# SyntaxError: invalid syntax
